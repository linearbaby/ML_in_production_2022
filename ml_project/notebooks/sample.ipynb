# %%
# %matplotlib inline

#importing the libraries
from matplotlib import pyplot as plt
import numpy as np
import pandas as pd
from sklearn.datasets import load_breast_cancer
#importing our cancer dataset


data = load_breast_cancer(as_frame=True)

# %%
df = data.frame

# %%
df.describe()
# Out:
#        mean radius  mean texture  mean perimeter    mean area  \
# count   569.000000    569.000000      569.000000   569.000000
# mean     14.127292     19.289649       91.969033   654.889104
# std       3.524049      4.301036       24.298981   351.914129
# min       6.981000      9.710000       43.790000   143.500000
# 25%      11.700000     16.170000       75.170000   420.300000
# 50%      13.370000     18.840000       86.240000   551.100000
# 75%      15.780000     21.800000      104.100000   782.700000
# max      28.110000     39.280000      188.500000  2501.000000
#
#        mean smoothness  mean compactness  mean concavity  mean concave points  \
# count       569.000000        569.000000      569.000000           569.000000
# mean          0.096360          0.104341        0.088799             0.048919
# std           0.014064          0.052813        0.079720             0.038803
# min           0.052630          0.019380        0.000000             0.000000
# ...

# %%
df.corr()
# Out:
#                          mean radius  mean texture  mean perimeter  mean area  \
# mean radius                 1.000000      0.323782        0.997855   0.987357
# mean texture                0.323782      1.000000        0.329533   0.321086
# mean perimeter              0.997855      0.329533        1.000000   0.986507
# mean area                   0.987357      0.321086        0.986507   1.000000
# mean smoothness             0.170581     -0.023389        0.207278   0.177028
# mean compactness            0.506124      0.236702        0.556936   0.498502
# mean concavity              0.676764      0.302418        0.716136   0.685983
# mean concave points         0.822529      0.293464        0.850977   0.823269
# mean symmetry               0.147741      0.071401        0.183027   0.151293
# mean fractal dimension     -0.311631     -0.076437       -0.261477  -0.283110
# radius error                0.679090      0.275869        0.691765   0.732562
# ...

# %%
f = plt.figure(figsize=(10, 10))
plt.matshow(df.corr())
plt.show()

# %% [markdown]
# #### Последующий участок кода падает в VS code.

# %%
# fig, axes = plt.subplots(len(df.columns), len(df.columns), figsize=(20, 20))
# for ax_row, column1 in zip(axes, df.columns):
#     for ax, column2 in zip(ax_row, df.columns):
#         ax.scatter(df[column1], df[column2])

# plt.show()

# %%
# fig, axes = plt.subplots(len(df.columns), len(df.columns), figsize=(20, 20))
# axes

# %%
# df = df.iloc[:, :-1]
# df.to_csv("breasts_cancer_eval.csv")

# %% [markdown]
# #### Sanity check

# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.impute import SimpleImputer
from sklearn.model_selection import train_test_split


def process_numerical_features(data_row: pd.DataFrame) -> pd.DataFrame:
    si = SimpleImputer()
    data_row = si.fit_transform(data_row)
    ss = StandardScaler()
    data_row = ss.fit_transform(data_row)
    return data_row


def process_categorical_features(data_row: pd.Series) -> pd.Series:
    si = SimpleImputer(strategy='constant', fill_value='M')
    data_row = si.fit_transform(data_row)
    ohe = OneHotEncoder(categories=['object'])
    data_row = ohe.fit_transform(data_row)
    return data_row

def process_dataset(dataset: pd.DataFrame) -> pd.DataFrame:
    pass

# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.impute import SimpleImputer
from sklearn.model_selection import train_test_split
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from omegaconf import DictConfig


def process_numerical_features() -> Pipeline:
    """Generate transforms for numerical columns"""
    numeric_transformer = Pipeline(
        steps=[
            ("imputer", SimpleImputer(strategy="median")),
            ("scaler", StandardScaler()),
        ]
    )
    return numeric_transformer


def process_categorical_features() -> Pipeline:
    """Generate transforms for categorical columns"""
    categoric_transformer = Pipeline(
        steps=[
            ("imputer", SimpleImputer(strategy="constant", fill_value="M")),
            ("scaler", OneHotEncoder()),
        ]
    )
    return categoric_transformer


def preprocess_pipeline(dataset: pd.DataFrame) -> tuple:
    target = dataset.to_numpy()[:, -1]
    dataset = dataset.iloc[:, :-1:]
    preprocessor = ColumnTransformer(
        transformers=[
            (
                "num",
                process_numerical_features,
                dataset.select_dtypes(include=["int64", "float64"]).columns,
            ),
            (
                "cat",
                process_categorical_features,
                dataset.select_dtypes(include=["object"]).columns,
            ),
        ]
    )
    return train_test_split(
        preprocessor.fit_transform(dataset),
        target,
        test_size=0.2,
        random_state=1,
    )

# %%
target = df.to_numpy()[:, -1]
dataset = df.iloc[:, :-1:]
preprocessor = ColumnTransformer(
        transformers=[
            (
                "num",
                process_numerical_features(),
                dataset.select_dtypes(include=["int64", "float64"]).columns,
            ),
            (
                "cat",
                process_categorical_features(),
                dataset.select_dtypes(include=["object"]).columns,
            ),
        ]
    )

# %%
preprocessor.fit_transform(dataset)
# Out:
# array([[ 1.09706398, -2.07333501,  1.26993369, ...,  2.10952635,
#          2.29607613,  2.75062224],
#        [ 1.82982061, -0.35363241,  1.68595471, ..., -0.14674897,
#          1.0870843 , -0.24388967],
#        [ 1.57988811,  0.45618695,  1.56650313, ...,  0.85497394,
#          1.95500035,  1.152255  ],
#        ...,
#        [ 0.70228425,  2.0455738 ,  0.67267578, ...,  0.3267666 ,
#          0.41406869, -1.10454895],
#        [ 1.83834103,  2.33645719,  1.98252415, ...,  3.19760468,
#          2.28998549,  1.91908301],
#        [-1.80840125,  1.22179204, -1.81438851, ..., -1.30583065,
#         -1.74506282, -0.04813821]])

# %%
train_test_split(
        preprocessor.fit_transform(dataset),
        target,
        test_size=0.2,
        random_state=1,
    )
# Out:
# [array([[ 1.09706398,  0.31888999,  1.06398269, ...,  0.27783186,
#           1.26066751,  0.25762232],
#         [ 1.75029663, -1.15181643,  1.77657315, ...,  0.61317876,
#           0.72925926, -0.86835298],
#         [-1.45622364, -1.13785403, -1.46674322, ..., -1.23521111,
#          -1.53356538,  0.14599546],
#         ...,
#         [ 0.87269277,  1.2171379 ,  0.91569797, ...,  1.8442233 ,
#           1.14646802,  0.66692082],
#         [-0.02763224,  0.45618695, -0.08975482, ..., -1.00689696,
#          -0.53256887, -1.09160671],
#         [-0.31164643, -0.20237305, -0.38550046, ..., -1.07396634,
#          -0.98175349, -1.47825627]]),
#  array([[ 0.15981713, -1.23559085,  0.25747857, ...,  0.23849217,
#          -0.05795583, -0.11932056],
#         [-0.27188444, -0.14652343, -0.24668948, ...,  1.09580963,
#           1.43425072,  1.61655804],
#         [-0.33436757, -0.76086916, -0.36366965, ..., -0.23070563,
#          -0.13713413,  0.77531212],
#         ...,
# ...

# %%
dataset.describe()
# Out:
#        mean radius  mean texture  mean perimeter    mean area  \
# count   569.000000    569.000000      569.000000   569.000000
# mean     14.127292     19.289649       91.969033   654.889104
# std       3.524049      4.301036       24.298981   351.914129
# min       6.981000      9.710000       43.790000   143.500000
# 25%      11.700000     16.170000       75.170000   420.300000
# 50%      13.370000     18.840000       86.240000   551.100000
# 75%      15.780000     21.800000      104.100000   782.700000
# max      28.110000     39.280000      188.500000  2501.000000
#
#        mean smoothness  mean compactness  mean concavity  mean concave points  \
# count       569.000000        569.000000      569.000000           569.000000
# mean          0.096360          0.104341        0.088799             0.048919
# std           0.014064          0.052813        0.079720             0.038803
# min           0.052630          0.019380        0.000000             0.000000
# ...
